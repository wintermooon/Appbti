# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
# %matplotlib inline

# %%
data = pd.read_csv('C:/Users/UserK/Desktop/archive/Google-Playstore.csv')

# %%
rating0 = data[data['Rating'] == 0.0].index
data = data.drop(rating0)

# %%
install0 = data[data['Maximum Installs'] == 0].index
data = data.drop(install0)

# %%
install = data[data['Maximum Installs'] < 75000000].index
data = data.drop(install)

# %%
data = data.drop(data.columns[[4,5,6,11,12,13,14,15,19,23]], axis=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\UserK\Desktop\google-data\db.ipynb Cell 6' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/UserK/Desktop/google-data/db.ipynb#ch0000010?line=0'>1</a> data = data.drop(data.columns[[4,5,6,11,12,13,14,15,19,23]], axis=1)
#       <a href='vscode-notebook-cell:/c%3A/Users/UserK/Desktop/google-data/db.ipynb#ch0000010?line=1'>2</a> data
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5055, in Index.__getitem__(self, key)
#    <a href='file:///c%3A/Users/UserK/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/indexes/base.py?line=5047'>5048</a> if com.is_bool_indexer(key):
# ...

# %%
data
# Out:
#                                                   App Name  \
# 1313     Screen Recorder, Video Recorder, V Recorder Ed...
# 3136                                     Archery Master 3D
# 9657                                             LokiCraft
# 15871                                        Samsung Email
# 20402                                       Fast Racing 3D
# ...                                                    ...
# 2304130                                         My Verizon
# 2305532                               Google Pay (old app)
# 2307317                               Google Authenticator
# 2310951                                 Microsoft OneDrive
# 2311951                            Good Pizza, Great Pizza
#
#                                          App Id                 Category  \
# 1313             screenrecorder.recorder.editor  Video Players & Editors
# 3136                      com.junerking.archery                   Sports
# ...

# %%
data.to_csv('pre-app.csv', index=False)
